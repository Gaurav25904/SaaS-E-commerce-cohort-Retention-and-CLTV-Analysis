# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a8bec236-41e9-49df-b96c-49895482c3b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8bec236-41e9-49df-b96c-49895482c3b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_2009 = pd.read_excel("online_retail_II.xlsx", sheet_name="Year 2009-2010")
df_2010 = pd.read_excel("online_retail_II.xlsx", sheet_name="Year 2010-2011")

df = pd.concat([df_2009, df_2010], ignore_index=True)

# %%
df["InvoiceDate"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %%
df["InvoiceDate"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Year"] = df["InvoiceDate"].dt.year
df["Month"] = df["InvoiceDate"].dt.month
df["Day"] = df["InvoiceDate"].dt.day
df["Day_Name"] = df["InvoiceDate"].dt.day_name()

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Year  Month  Day  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12    1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009     12    1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12    1
#
#   Day_Name
# 0  Tuesday
# 1  Tuesday
# 2  Tuesday
# 3  Tuesday
# 4  Tuesday

# %%
df["InvoiceDate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Year"].value_counts()
df["Month"].value_counts().sort_index()
# Out:
# Month
# 1      66702
# 2      57095
# 3      78259
# 4      63973
# 5      72353
# 6      76857
# 7      72901
# 8      68590
# 9      92317
# 10    119840
# 11    162726
# 12    135758
# Name: count, dtype: int64

# %%
df.to_csv("processed_online_retail.csv", index=False)

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'processed_online_retail.csv',
#  'online_retail_II.xlsx',
#  'sample_data']

# %%
from google.colab import files

files.download("processed_online_retail.csv")
