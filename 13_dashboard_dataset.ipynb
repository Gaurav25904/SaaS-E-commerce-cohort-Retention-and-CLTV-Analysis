# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-84c236c0-68d7-45f4-80b8-b2d91cb3e2a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84c236c0-68d7-45f4-80b8-b2d91cb3e2a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

cohort_df = pd.read_csv("cohort_index_dataset.csv")
segment_df = pd.read_csv("customer_segmentation.csv")

# %%
dashboard_df = cohort_df.merge(
    segment_df,
    on="Customer ID",
    how="left"
)

dashboard_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  Year  Month  ...  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12  ...
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12  ...
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12  ...
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009     12  ...
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12  ...
#
#    Day_Name  First_Purchase_Date Cohort_Month Order_Month Revenue  \
# ...

# %%
total_revenue = dashboard_df["Revenue"].sum()
total_customers = dashboard_df["Customer ID"].nunique()
total_orders = dashboard_df["Invoice"].nunique()

# %% [markdown]
# 3. Power BI visuals ki list
#
# Dashboard me ye visuals rakho:
# **bold text**
#
# KPI Cards
#
# Monthly Revenue Trend
#
# Cohort Retention Heatmap
#
# Customer Segmentation
#
#  Pie Chart
#
# Top Customers by Revenue
#
# Orders by Month
#
# CLTV Analysis

# %%
dashboard_df.to_csv(
    "dashboard_dataset.csv",
    index=False
)

# %%
from google.colab import files

files.download("dashboard_dataset.csv")
