# %%
import pandas as pd

# %%
df = pd.read_csv("retail_with_first_purchase.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410763 entries, 0 to 410762
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Invoice            410763 non-null  object
#  1   StockCode          410763 non-null  object
#  2   Description        410763 non-null  object
#  3   Quantity           410763 non-null  int64
#  4   InvoiceDate        410763 non-null  object
#  5   Price              410763 non-null  float64
#  6   Customer ID        410763 non-null  float64
#  7   Country            410763 non-null  object
#  8   FirstPurchaseDate  410763 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 28.2+ MB

# %%
df.isnull().sum()
# Out:
# Invoice              0
# StockCode            0
# Description          0
# Quantity             0
# InvoiceDate          0
# Price                0
# Customer ID          0
# Country              0
# FirstPurchaseDate    0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0
